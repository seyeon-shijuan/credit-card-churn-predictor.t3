# %%
import pickle

with open('base_dataset_standardized.pkl','rb') as file:
  data=pickle.load(file)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer_Age               10127 non-null  float64
#  1   Dependent_count            10127 non-null  float64
#  2   Education_Level            10127 non-null  float64
#  3   Income_Category            10127 non-null  float64
#  4   Card_Category              10127 non-null  float64
#  5   Months_on_book             10127 non-null  float64
#  6   Total_Relationship_Count   10127 non-null  float64
#  7   Months_Inactive_12_mon     10127 non-null  float64
#  8   Contacts_Count_12_mon      10127 non-null  float64
#  9   Credit_Limit               10127 non-null  float64
#  10  Total_Revolving_Bal        10127 non-null  float64
#  11  Total_Amt_Chng_Q4_Q1       10127 non-null  float64
#  12  Total_Trans_Amt            10127 non-null  float64
#  13  Total_Trans_Ct             10127 non-null  float64
#  14  Total_Ct_Chng_Q4_Q1        10127 non-null  float64
#  15  Avg_Utilization_Ratio      10127 non-null  float64
#  16  Gender_Male                10127 non-null  float64
#  17  Marital_Status_Uneducated  10127 non-null  float64
#  18  Marital_Status_Single      10127 non-null  float64
#  19  Marital_Status_Divorced    10127 non-null  float64
#  20  Attrition_Flag             10127 non-null  int64
# dtypes: float64(20), int64(1)
# memory usage: 1.6 MB

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

y=data["Attrition_Flag"]
x=data.drop(["Attrition_Flag"],axis=1)

X_train, X_test, y_train, y_test= train_test_split(x, y, test_size=0.3, random_state=0, stratify=y)

print(X_train.shape, X_test.shape)
# Out:
# (7088, 20) (3039, 20)

# %%
model=DecisionTreeClassifier(random_state=0)
model.fit(X_train, y_train)

accuracy=model.score(X_test, y_test)
y_predict=model.predict(X_test)

print(f'{accuracy=:.4f}')
# Out:
# accuracy=0.9424

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

cm=confusion_matrix(y_test, y_predict)

cm
# Out:
# array([[2443,   81],
#        [  94,  421]])

# %%
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predict")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
Accuracy = accuracy_score(y_test, y_predict)
Precision = precision_score(y_test, y_predict)
Recall = recall_score(y_test, y_predict)
F1 = f1_score(y_test, y_predict)

print("Accuracy:%.4f"%Accuracy)
print("Precision:%.4f"%Precision)
print("Recall:%.4f"%Recall)
print("F1:%.4f"%F1)
# Out:
# Accuracy:0.9424
# Precision:0.8386
# Recall:0.8175
# F1:0.8279

# %%
from sklearn.ensemble import RandomForestClassifier

model= RandomForestClassifier(random_state=0)
model.fit(X_train, y_train)

accuracy=model.score(X_test, y_test)
y_predict=model.predict(X_test)

print(f'{accuracy=:.4f}')
# Out:
# accuracy=0.9605

# %%
cm=confusion_matrix(y_test, y_predict)

print(cm)
# Out:
# array([[2504,   20],
#        [ 100,  415]])

# %%
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predict")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
Accuracy = accuracy_score(y_test, y_predict)
Precision = precision_score(y_test, y_predict)
Recall = recall_score(y_test, y_predict)
F1 = f1_score(y_test, y_predict)

print("Accuracy:%.4f"%Accuracy)
print("Precision:%.4f"%Precision)
print("Recall:%.4f"%Recall)
print("F1:%.4f"%F1)
# Out:
# Accuracy:0.9605
# Precision:0.9540
# Recall:0.8058
# F1:0.8737

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.11.3)

# %%
import lightgbm as lgb

model=lgb.LGBMClassifier(random_state=0)
model.fit(X_train, y_train)

accuracy=model.score(X_test, y_test)
y_predict=model.predict(X_test)

print(f'{accuracy=:.4f}')
# Out:
# [LightGBM] [Info] Number of positive: 1112, number of negative: 5976
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001262 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1801
# [LightGBM] [Info] Number of data points in the train set: 7088, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.156885 -> initscore=-1.681591
# [LightGBM] [Info] Start training from score -1.681591
# accuracy=0.9766

# %%
cm=confusion_matrix(y_test, y_predict)

cm
# Out:
# array([[2500,   24],
#        [  47,  468]])

# %%
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predict")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
Accuracy = accuracy_score(y_test, y_predict)
Precision = precision_score(y_test, y_predict)
Recall = recall_score(y_test, y_predict)
F1 = f1_score(y_test, y_predict)

print("Accuracy:%.4f"%Accuracy)
print("Precision:%.4f"%Precision)
print("Recall:%.4f"%Recall)
print("F1:%.4f"%F1)
# Out:
# Accuracy:0.9766
# Precision:0.9512
# Recall:0.9087
# F1:0.9295

# %%
# !pip install XGboost
# Out:
# Requirement already satisfied: XGboost in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from XGboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from XGboost) (1.11.3)

# %%
from sklearn.ensemble import BaggingClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier

# %%
##BaggingClassifier

model= BaggingClassifier(random_state=0)
model.fit(X_train, y_train)

accuracy=model.score(X_test, y_test)
y_predict=model.predict(X_test)

print(f'{accuracy=:.4f}',"\n")

cm=confusion_matrix(y_test, y_predict)

print("confusion matrix value:\n",cm,"\n")

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predict")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

Accuracy = accuracy_score(y_test, y_predict)
Precision = precision_score(y_test, y_predict)
Recall = recall_score(y_test, y_predict)
F1 = f1_score(y_test, y_predict)

print("Accuracy:%.4f"%Accuracy)
print("Precision:%.4f"%Precision)
print("Recall:%.4f"%Recall)
print("F1:%.4f"%F1)
# Out:
# accuracy=0.9592
#
# confusion matrix value:
#  [[2494   30]
#  [  94  421]]
#
# Accuracy:0.9592
# Precision:0.9335
# Recall:0.8175
# F1:0.8716

# %%
##GradientBoostingClassifier

model= GradientBoostingClassifier(random_state=0)
model.fit(X_train, y_train)

accuracy=model.score(X_test, y_test)
y_predict=model.predict(X_test)

print(f'{accuracy=:.4f}',"\n")

cm=confusion_matrix(y_test, y_predict)

print("confusion matrix value:\n",cm,"\n")

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predict")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

Accuracy = accuracy_score(y_test, y_predict)
Precision = precision_score(y_test, y_predict)
Recall = recall_score(y_test, y_predict)
F1 = f1_score(y_test, y_predict)

print("Accuracy:%.4f"%Accuracy)
print("Precision:%.4f"%Precision)
print("Recall:%.4f"%Recall)
print("F1:%.4f"%F1)
# Out:
# accuracy=0.9691
#
# confusion matrix value:
#  [[2502   22]
#  [  72  443]]
#
# Accuracy:0.9691
# Precision:0.9527
# Recall:0.8602
# F1:0.9041

# %%
##AdaBoostClassifier

model= AdaBoostClassifier(random_state=0)
model.fit(X_train, y_train)

accuracy=model.score(X_test, y_test)
y_predict=model.predict(X_test)

print(f'{accuracy=:.4f}',"\n")

cm=confusion_matrix(y_test, y_predict)

print("confusion matrix value:\n",cm,"\n")

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predict")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

Accuracy = accuracy_score(y_test, y_predict)
Precision = precision_score(y_test, y_predict)
Recall = recall_score(y_test, y_predict)
F1 = f1_score(y_test, y_predict)

print("Accuracy:%.4f"%Accuracy)
print("Precision:%.4f"%Precision)
print("Recall:%.4f"%Recall)
print("F1:%.4f"%F1)
# Out:
# accuracy=0.9612
#
# confusion matrix value:
#  [[2486   38]
#  [  80  435]]
#
# Accuracy:0.9612
# Precision:0.9197
# Recall:0.8447
# F1:0.8806

# %%
##XGBClassifier

model= XGBClassifier(random_state=0)
model.fit(X_train, y_train)

accuracy=model.score(X_test, y_test)
y_predict=model.predict(X_test)

print(f'{accuracy=:.4f}',"\n")

cm=confusion_matrix(y_test, y_predict)

print("confusion matrix value:\n",cm,"\n")

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predict")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

Accuracy = accuracy_score(y_test, y_predict)
Precision = precision_score(y_test, y_predict)
Recall = recall_score(y_test, y_predict)
F1 = f1_score(y_test, y_predict)

print("Accuracy:%.4f"%Accuracy)
print("Precision:%.4f"%Precision)
print("Recall:%.4f"%Recall)
print("F1:%.4f"%F1)
# Out:
# accuracy=0.9740
#
# confusion matrix value:
#  [[2500   24]
#  [  55  460]]
#
# Accuracy:0.9740
# Precision:0.9504
# Recall:0.8932
# F1:0.9209
