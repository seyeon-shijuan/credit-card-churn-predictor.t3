# %%
# !pip install AutoViz
# !pip install xlrd

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import datetime as dt

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
# Load data
# file = '../../data/BankChurners.csv'
# df = pd.read_csv(file)
# df = df.iloc[:,1:-2]
# df.head()

# 전처리 완료
# file = "../../data/base_dataset_standardized.pkl"
file = "../../data/base_dataset_before_std.pkl"
df = pd.read_pickle(file)

df.head()
# Out:
#    Customer_Age  Dependent_count  Education_Level  Income_Category  \
# 0       45              3                2                3
# 1       49              5                3                1
# 2       51              3                3                4
# 3       40              4                2                1
# 4       40              3                1                3
#
#    Card_Category  Months_on_book  Total_Relationship_Count  \
# 0        1              39                    5
# 1        1              44                    6
# 2        1              36                    4
# 3        1              34                    3
# 4        1              21                    5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0             1                      3               12691.0
# 1             1                      2                8256.0
# 2             1                      0                3418.0
# ...

# %%
# method2 : Visualization for independant Vs Dependant variable
# save results to html
save_viz_dir = 'eda_viz'
dftc = AV.AutoViz(filename='', 
                  sep =',' , 
                  depVar ='Attrition_Flag', 
                  dfte = df, 
                  header = 0, 
                  verbose = 2,  # print extra information on the notebook and also display charts
                  lowess = False, 
                  chart_format ='html', 
                  max_rows_analyzed = 15000, 
                  max_cols_analyzed = 30,
                  save_plot_dir = save_viz_dir
)
# Out:
# Shape of your Data Set loaded: (10127, 21)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing upto 30 columns max in each category:
#     Numeric Columns : ['Credit_Limit', 'Total_Amt_Chng_Q4_Q1', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
#     Integer-Categorical Columns: ['Customer_Age', 'Dependent_count', 'Education_Level', 'Income_Category', 'Card_Category', 'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Total_Revolving_Bal', 'Total_Trans_Amt', 'Total_Trans_Ct']
#     String-Categorical Columns: []
#     Factor-Categorical Columns: []
# ...
